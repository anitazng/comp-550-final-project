# %%
from pypinyin import pinyin, lazy_pinyin, Style
import numpy as np
from gensim.models import Word2Vec
import csv
import pandas as pd
from collections import defaultdict
from collections import Counter

# %%
df = pd.read_csv('./transcripts.tsv')
sentences = df.values.tolist()
tokenized_sentences = []
for sentence in sentences:
        tokenized_sentences.append(list("".join(sentence)))
model = Word2Vec(tokenized_sentences, vector_size=300, epochs=200)
model.wv['一']
model.wv.most_similar('一', topn=10)
# Out:
# [('曲', 0.25715118646621704),
#  ('载', 0.22268685698509216),
#  ('几', 0.2162376046180725),
#  ('写', 0.2124497890472412),
#  ('歌', 0.2081436961889267),
#  ('过', 0.20675060153007507),
#  ('静', 0.2063993364572525),
#  ('选', 0.19986645877361298),
#  ('山', 0.1994759887456894),
#  ('最', 0.19761230051517487)]

# %%
list_of_char = model.wv.index_to_key
count = 0
correct = 0
for char in list_of_char:
    pinyin = lazy_pinyin(char, style=Style.TONE3)
    list_of_similar = model.wv.most_similar(char, topn=10)
    similar_char = []
    count += 1
    for i in list_of_similar:
        if lazy_pinyin(i[0], style=Style.TONE3) == pinyin:
            correct += 1
            break
print("the accuracy ", correct / count * 100)
# Out:
# the accuracy  1.746031746031746

# %%
homophone_groups = defaultdict(list)
chars = list(model.wv.index_to_key)
for char in chars:
        pinyin = lazy_pinyin(char, style=Style.TONE3)
        homophone_groups["".join(pinyin)].append((char, model.wv[char]))
for pinyin, embeddings in homophone_groups.items():
    if len(embeddings) > 1:
        print(f'{pinyin}: {[char for (char, _) in embeddings]}')
# Out:
# yi1: ['一', '衣']
# ge1: ['歌', '哥']
# bu4: ['不', '部']
# ge4: ['个', '各']
# shi4: ['是', '事', '视', '室', '氏', '市', '式', '试', '世', '似', '适']
# you3: ['有', '友']
# shou3: ['首', '手']
# zai4: ['在', '再', '载']
# qu1: ['曲', '区']
# ma: ['吗', '嘛']
# qi4: ['气', '器']
# shang4: ['上', '尚']
# dian3: ['点', '典']
# dao4: ['到', '道', '倒']
# ji2: ['集', '辑', '吉', '急']
# di4: ['第', '地']
# hai2: ['还', '孩']
# ming2: ['明', '名']
# jia1: ['家', '加']
# shi2: ['十', '时', '识', '实']
# yi3: ['以', '已']
# hua4: ['话', '化']
# xin1: ['新', '心', '欣']
# li3: ['里', '李', '理', '礼']
# yu3: ['雨', '语', '与']
# dian4: ['电', '店']
# ta1: ['他', '她']
# wei4: ['为', '位', '卫', '未']
# xian4: ['现', '线', '县']
# xing2: ['行', '型']
# zhi1: ['知', '之']
# wu3: ['五', '午', '舞', '武']
# er2: ['儿', '而']
# ji3: ['几', '己']
# zhong1: ['中', '钟']
# he2: ['和', '何', '合', '河']
# hou4: ['后', '候']
# zi4: ['自', '字']
# jiao4: ['叫', '较']
# sheng1: ['生', '声']
# jiu3: ['九', '酒', '久']
# bian4: ['变', '便']
# liu2: ['流', '刘']
# ji1: ['机', '鸡']
# gang1: ['刚', '钢']
# xi3: ['喜', '洗']
# ru2: ['如', '茹']
# she4: ['摄', '设']
# yue4: ['月', '越']
# zhou1: ['周', '州']
# gong1: ['公', '工']
# jie2: ['杰', '节', '结']
# de2: ['得', '德']
# jian4: ['见', '荐', '件', '健', '建']
# yi4: ['意', '易', '忆']
# jing1: ['经', '京']
# yan3: ['演', '眼']
# mei3: ['美', '每']
# zuo4: ['做', '作', '座', '坐']
# qi1: ['七', '期']
# ti2: ['提', '题']
# xi4: ['系', '戏']
# jin4: ['近', '进']
# fu2: ['服', '福']
# su4: ['诉', '宿', '速']
# wan2: ['玩', '完']
# wang3: ['网', '往']
# wen2: ['文', '闻']
# zhi3: ['只', '址', '指']
# ji4: ['记', '计']
# you4: ['又', '右']
# wu2: ['无', '吴']
# tong2: ['同', '童']
# zheng4: ['正', '郑', '证']
# huo3: ['火', '伙']
# mu4: ['目', '木']
# nan2: ['南', '难', '男']
# fu4: ['负', '复', '附', '父']
# dong4: ['动', '冻']
# ying1: ['英', '应']
# zhu4: ['注', '祝']
# si1: ['司', '思']
# fei1: ['非', '飞']
# ke4: ['克', '客', '课']
# qi2: ['齐', '奇']
# ban4: ['办', '半', '伴']
# jiang1: ['江', '将']
# yu4: ['预', '遇']
# bao3: ['宝', '保']
# xiang1: ['相', '香']
# qian2: ['前', '钱']
# xi1: ['西', '息', '惜']
# yu2: ['于', '鱼', '余']
# qing1: ['青', '清']
# jie3: ['姐', '解']
# cheng2: ['成', '城']
# shu1: ['书', '舒']
# bei4: ['贝', '被', '备', '背']
# liang4: ['亮', '量']
# dan4: ['但', '蛋', '弹']
# ye4: ['夜', '业']
# xing1: ['星', '兴']
# li4: ['力', '立', '利']
# zhi4: ['制', '治']
# dai4: ['带', '代']
# jing4: ['静', '敬']
# xiao4: ['笑', '校']
# pu3: ['普', '谱']
# jiao1: ['交', '郊']
# ju4: ['句', '剧']
# qin2: ['琴', '秦']
# luo4: ['络', '落']
# gou4: ['购', '够']
# shu4: ['数', '术']
# wang4: ['忘', '望']
# liang2: ['凉', '良', '梁']
# lei4: ['累', '类', '泪']
# duan4: ['断', '段']
# wei2: ['围', '维']
# wu4: ['务', '物']
# zhao4: ['赵', '照']
# hei1: ['嘿', '黑']
# jie4: ['介', '界']
# yang2: ['杨', '阳']

# %%
frequencies = Counter()
reverse_frequencies = defaultdict(list)
sentences = df.values.tolist()
tokenized_sentences = []
for sentence in sentences:
        tokenized_sentences.append(list("".join(sentence)))

for sentence in tokenized_sentences:
        frequencies.update(sentence)
        
for word, freq in frequencies.items():
        reverse_frequencies[freq].append(word)
print(reverse_frequencies)
print(frequencies)
# Out:
# defaultdict(<class 'list'>, {649: ['我'], 26: ['喜', '刚', '摄', '月', '走', '如', '调'], 25: ['欢', '热', '室', '分', '名'], 90: ['那'], 4: ['颜', '艺', '及', '震', '川', '严', '烦', '悲', '吹', '骂', '票', '持', '初', '逼', '广', '待', '呵', '志', '惠', '医', '贞', '平', '宇', '番', '雾', '谈', '恋', '朝', '米', '洋', '留', '冰', '取', '步', '脸', '土', '套', '智', '罗', '慧', '堵', '插', '街', '济', '葛', '队', '津', '滚', '深', '任', '搜', '份', '决', '乡', '希', '若', '遍', '瓜', '千', '社', '顾
', '规', '陀', '夹', '云', '统', '笨', '扰', '付', '悟', '追', '床', '艳', '配', '耍', '款', '姑', '迎', '弱', '蜗', '居', '龄', '叶', '倩', '阶', '秒', '央', '存', '凯', '盛', '奋', '斗', '症', '喂', '禁', '暖', '忽', '眯', '占', '偷', '兜', '寒', '拍', '哒', '领', '疯', '叔', '丞', '昵', '暗', '喱'], 7: ['休', '特', '购', '品', '复', '县', '处', '者', '口', '州', '差', '孩', '洗', '赏', '备', '傻', '与', '约', '雪', '易', '校', '总', '牛', '实', '忆', '忘', '累', '店', '数', '建', '解', '庆', '防', '当', '凉', '格', '退', '先', '光'], 12: ['息', '昨', '档', '于', '青', '清', '空', '奏', '路', '眼', '前', '相', '西', '女', '难', '苏', '许', '飞', '嘛', '衣', '位', '姐', '越'], 458: ['一'], 216: ['下'], 29: ['年', '候', '等', '找', '变', '九'], 300: ['天'], 46: ['子'], 83: ['第', '大', '吧'], 85: ['集', '最', '看', '这'], 56: ['们', '乐', '小', '呢'], 17: ['通', '求', '台', '记', '载', '李', '频', '词', '荐'], 44: ['过', '出', '儿', '五', '知'], 297: ['不'], 16: ['同', '零', '无', '伤', '认', '接', '又', '林', '门', '场', '京'], 710: ['的'], 31: ['手', '辑', '快', '叫'], 6: ['段', '各', '鱼', '停', '冻', '满', '跳', '器', '赵', '宿', '管', '雄', '伴', '湖', '量', '院', '欣', '确', '指', '伟', '群', '物', '猪', '故', '谱', '倒', '立', '从', '怕', '浪', '兴', '蛋', '摇', '围', '证', '务', '伦', '久', '舞', '进', '嘿', '代', '算', '惜', '万', '思', '豆', '断', '落', '并', '炎', '山', '父', '况', '送', '军', '够', '咖', '附', '试', '雷', '答'], 3: ['独', '技', '巧', '形', '戴', '迅', '龙', '员', '赶', '楚', '止', '呗', '港', '曾', '羊', '辉', '晴', '启', '宅', '剑', '景', '阴', '马', '观', '压', '笔', '妞', '入', '瑞', '育', '论', '毛', '呐', '镇', '借', ...
# Counter({'的': 710, '我': 649, '一': 458, '歌': 375, '你': 371, '天': 300, '了': 298, '不': 297, '放': 273, '来': 267, '个': 234, '下': 216, '播': 214, '是': 211, '有': 193, '好': 191, '给': 188, '首': 187, '听': 161, '要': 153, '在': 145, '曲': 128, '吗': 127, '气': 127, '想': 125, '请': 122, '上': 119, '么': 116, '去': 109, '啊': 101, '点': 100, '说': 95, '会': 94, '人': 93, '就': 92, '那': 90, '到': 89, '没': 89, '集': 85, '最': 85, '看': 85, '这': 85, '第': 83, '大': 83, '吧': 83, '度': 79, '唱': 77, '还': 76, '明': 73, '打': 72, '回': 69, '家': 69, '十': 69, '以': 67, '可': 66, '话': 66, '新': 64, '道': 64, '温': 64, '哪': 63, '里': 63, '怎': 61, '开': 59, '音': 58, '时': 58, '样': 58, '电': 57, '雨': 57, '都': 57, '他': 57, '们': 56, '乐': 56, '小': 56, '呢': 56, '能': 55, '今': 55, '吃': 53, '什': 52, '为': 51, '也': 51, '老': 50, '多': 49, '行': 47, '现': 47, '谁': 47, '子': 46, '学': 45, '过': 44, '出': 44, '儿
': 10, '德': 10, '团': 10, '典': 10, '常': 10, '贝': 10, '转': 10, '闻': 10, '亮': 10, '练': 10, '传': 10, '远': 10, '花': 10, '游': 10, '但': 10, '费': 10, '喝': 10, '受': 10, '夜': 10, '红': 10, '星': 10, '件': 10, '已': 10, '吉': 10, '书': 10, '挺': 10, '语': 10, '身': 10, '降': 10, '式': 10, '朋': 10, '永': 10, '写': 10, '师': 10, '忙': 10, '运': 9, '制': 9, '带': 9, '全': 9, '合': 9, '该': 9, '理': 9, '妹': 9, '拿': 9, '力': 9, '微': 9, '容': 9, '而': 9, '民': 9, '静': 9, '亲': 9, '笑': 9, '菜': 9, '钟': 9, ' ': 9, '孙': 9, '奶': 9, '急': 9, '您': 9, '客': 8, '普': 8, '健': 8, '识': 8, '活': 8, '片': 8, '黄': 8, '每': 8, '爸': 8, '琴': 8, '离': 8, '句': 8, '百': 8, '城': 8, '底': 8, '便': 8, '结': 8, '哥': 8, '福': 8, '被': 8, '站': 8, '表': 8, '原': 8, '址': 8, '络': 8, '沙': 8, '课': 8, '交': 8, '休': 7, '特': 7, '购': 7, '品': 7, '复': 7, '县': 7, '处': 7, '者': 7, '口': 7, '州': 7, '差': 7, '孩': 7, '洗': 7, '赏': 7, '备': 7, '傻': 7, '与': 7, '约': 7, '雪': 7, '易': 7, '校': 7, '总': 7, '牛': 7, '实' ...

# %%
def calculate_similarity(model, word1, word2):
    return model.wv.similarity(word1, word2)

def calculate_average_similarity(similarity_sum, counter):
    return similarity_sum / counter if counter != 0 else 0

baseline_similarity_sum = 0
baseline_counter = 0
homophone_similarity_sum = 0
homophone_counter = 0

for homophones in homophone_groups.values():
    if len(homophones) > 1:
        for i, (h1, embedding1) in enumerate(homophones):
            for j, (h2, embedding2) in enumerate(homophones):
                if i != j:
                    frequency = frequencies[h2]
                    similar_frequency_chars = reverse_frequencies.get(frequency, [])
                    
                    for similar_frequency_char in similar_frequency_chars:
                        if similar_frequency_char != h1:
                            baseline_similarity_sum += calculate_similarity(model, h1, similar_frequency_char)
                            baseline_counter += 1
                    
                    print(h1)
                    print(h2)
                    print("a")
                    homophone_similarity_sum += calculate_similarity(model, h1, h2)
                    homophone_counter += 1

baseline_average = calculate_average_similarity(baseline_similarity_sum, baseline_counter)
homophone_average = calculate_average_similarity(homophone_similarity_sum, homophone_counter)

print(f'Average Baseline Similarity: {baseline_average}')
print(f'Average Homophone Group Similarity: {homophone_average}')
print(f'Difference Between Average Baseline and Homophone Similarities: {baseline_average - homophone_average}')
# Out:
# 一
# 衣
# a
# 衣
# 一
# a
# 歌
# 哥
# a
# 哥
# 歌
# a
# 不
# 部
# a
# 部
# 不
# a
# 个
# 各
# a
# 各
# 个
# a
# 是
# 事
# a
# 是
# 视
# a
# 是
# 室
# a
# 是
# 氏
# a
# 是
# 市
# a
# 是
# 式
# a
# 是
# 试
# a
# 是
# 世
# a
# 是
# 似
# a
# 是
# 适
# a
# 事
# 是
# a
# 事
# 视
# a
# 事
# 室
# a
# 事
# 氏
# a
# 事
# 市
# a
# 事
# 式
# a
# 事
# 试
# a
# 事
# 世
# a
# 事
# 似
# a
# 事
# 适
# a
# 视
# 是
# a
# 视
# 事
# a
# 视
# 室
# a
# 视
# 氏
# a
# 视
# 市
# a
# 视
# 式
# a
# 视
# 试
# a
# 视
# 世
# a
# 视
# 似
# a
# 视
# 适
# a
# 室
# 是
# a
# 室
# 事
# a
# 室
# 视
# a
# 室
# 氏
# a
# 室
# 市
# a
# 室
# 式
# a
# 室
# 试
# a
# 室
# 世
# a
# 室
# 似
# a
# 室
# 适
# a
# 氏
# 是
# a
# 氏
# 事
# a
# 氏
# 视
# a
# 氏
# 室
# a
# 氏
# 市
# a
# 氏
# 式
# a
# 氏
# 试
# a
# 氏
# 世
# a
# 氏
# 似
# a
# 氏
# 适
# a
# 市
# 是
# a
# 市
# 事
# a
# 市
# 视
# a
# 市
# 室
# a
# 市
# 氏
# a
# 市
# 式
# a
# 市
# 试
# a
# 市
# 世
# a
# 市
# 似
# a
# 市
# 适
# a
# 式
# 是
# a
# 式
# 事
# a
# 式
# 视
# a
# 式
# 室
# a
# 式
# 氏
# a
# 式
# 市
# a
# 式
# 试
# a
# 式
# 世
# a
# 式
# 似
# a
# 式
# 适
# a
# 试
# 是
# a
# 试
# 事
# a
# 试
# 视
# a
# 试
# 室
# a
# 试
# 氏
# a
# 试
# 市
# a
# 试
# 式
# a
# 试
# 世
# a
# 试
# 似
# a
# 试
# 适
# a
# 世
# 是
# a
# 世
# 事
# a
# 世
# 视
# a
# 世
# 室
# a
# 世
# 氏
# a
# 世
# 市
# a
# 世
# 式
# a
# 世
# 试
# a
# 世
# 似
# a
# 世
# 适
# a
# 似
# 是
# a
# 似
# 事
# a
# 似
# 视
# a
# 似
# 室
# a
# 似
# 氏
# a
# 似
# 市
# a
# 似
# 式
# a
# 似
# 试
# a
# 似
# 世
# a
# 似
# 适
# a
# 适
# 是
# a
# 适
# 事
# a
# 适
# 视
# a
# 适
# 室
# a
# 适
# 氏
# a
# 适
# 市
# a
# 适
# 式
# a
# 适
# 试
# a
# 适
# 世
# a
# 适
# 似
# a
# 有
# 友
# a
# 友
# 有
# a
# 首
# 手
# a
# 手
# 首
# a
# 在
# 再
# a
# 在
# 载
# a
# 再
# 在
# a
# 再
# 载
# a
# 载
# 在
# a
# 载
# 再
# a
# 曲
# 区
# a
# 区
# 曲
# a
# 吗
# 嘛
# a
# 嘛
# 吗
# a
# 气
# 器
# a
# 器
# 气
# a
# 上
# 尚
# a
# 尚
# 上
# a
# 点
# 典
# a
# 典
# 点
# a
# 到
# 道
# a
# 到
# 倒
# a
# 道
# 到
# a
# 道
# 倒
# a
# 倒
# 到
# a
# 倒
# 道
# a
# 集
# 辑
# a
# 集
# 吉
# a
# 集
# 急
# a
# 辑
# 集
# a
# 辑
# 吉
# a
# 辑
# 急
# a
# 吉
# 集
# a
# 吉
# 辑
# a
# 吉
# 急
# a
# 急
# 集
# a
# 急
# 辑
# a
# 急
# 吉
# a
# 第
# 地
# a
# 地
# 第
# a
# 还
# 孩
# a
# 孩
# 还
# a
# 明
# 名
# a
# 名
# 明
# a
# 家
# 加
# a
# 加
# 家
# a
# 十
# 时
# a
# 十
# 识
# a
# 十
# 实
# a
# 时
# 十
# a
# 时
# 识
# a
# 时
# 实
# a
# 识
# 十
# a
# 识
# 时
# a
# 识
# 实
# a
# 实
# 十
# a
# 实
# 时
# a
# 实
# 识
# a
# 以
# 已
# a
# 已
# 以
# a
# 话
# 化
# a
# 化
# 话
# a
# 新
# 心
# a
# 新
# 欣
# a
# 心
# 新
# a
# 心
# 欣
# a
# 欣
# 新
# a
# 欣
# 心
# a
# 里
# 李
# a
# 里
# 理
# a
# 里
# 礼
# a
# 李
# 里
# a
# 李
# 理
# a
# 李
# 礼
# a
# 理
# 里
# a
# 理
# 李
# a
# 理
# 礼
# a
# 礼
# 里
# a
# 礼
# 李
# a
# 礼
# 理
# a
# 雨
# 语
# a
# 雨
# 与
# a
# 语
# 雨
# a
# 语
# 与
# a
# 与
# 雨
# a
# 与
# 语
# a
# 电
# 店
# a
# 店
# 电
# a
# 他
# 她
# a
# 她
# 他
# a
# 为
# 位
# a
# 为
# 卫
# a
# 为
# 未
# a
# 位
# 为
# a
# 位
# 卫
# a
# 位
# 未
# a
# 卫
# 为
# a
# 卫
# 位
# a
# 卫
# 未
# a
# 未
# 为
# a
# 未
# 位
# a
# 未
# 卫
# a
# 现
# 线
# a
# 现
# 县
# a
# 线
# 现
# a
# 线
# 县
# a
# 县
# 现
# a
# 县
# 线
# a
# 行
# 型
# a
# 型
# 行
# a
# 知
# 之
# a
# 之
# 知
# a
# 五
# 午
# a
# 五
# 舞
# a
# 五
# 武
# a
# 午
# 五
# a
# 午
# 舞
# a
# 午
# 武
# a
# 舞
# 五
# a
# 舞
# 午
# a
# 舞
# 武
# a
# 武
# 五
# a
# 武
# 午
# a
# 武
# 舞
# a
# 儿
# 而
# a
# 而
# 儿
# a
# 几
# 己
# a
# 己
# 几
# a
# 中
# 钟
# a
# 钟
# 中
# a
# 和
# 何
# a
# 和
# 合
# a
# 和
# 河
# a
# 何
# 和
# a
# 何
# 合
# a
# 何
# 河
# a
# 合
# 和
# a
# 合
# 何
# a
# 合
# 河
# a
# 河
# 和
# a
# 河
# 何
# a
# 河
# 合
# a
# 后
# 候
# a
# 候
# 后
# a
# 自
# 字
# a
# 字
# 自
# a
# 叫
# 较
# a
# 较
# 叫
# a
# 生
# 声
# a
# 声
# 生
# a
# 九
# 酒
# a
# 九
# 久
# a
# 酒
# 九
# a
# 酒
# 久
# a
# 久
# 九
# a
# 久
# 酒
# a
# 变
# 便
# a
# 便
# 变
# a
# 流
# 刘
# a
# 刘
# 流
# a
# 机
# 鸡
# a
# 鸡
# 机
# a
# 刚
# 钢
# a
# 钢
# 刚
# a
# 喜
# 洗
# a
# 洗
# 喜
# a
# 如
# 茹
# a
# 茹
# 如
# a
# 摄
# 设
# a
# 设
# 摄
# a
# 月
# 越
# a
# 越
# 月
# a
# 周
# 州
# a
# 州
# 周
# a
# 公
# 工
# a
# 工
# 公
# a
# 杰
# 节
# a
# 杰
# 结
# a
# 节
# 杰
# a
# 节
# 结
# a
# 结
# 杰
# a
# 结
# 节
# a
# 得
# 德
# a
# 德
# 得
# a
# 见
# 荐
# a
# 见
# 件
# a
# 见
# 健
# a
# 见
# 建
# a
# 荐
# 见
# a
# 荐
# 件
# a
# 荐
# 健
# a
# 荐
# 建
# a
# 件
# 见
# a
# 件
# 荐
# a
# 件
# 健
# a
# 件
# 建
# a
# 健
# 见
# a
# 健
# 荐
# a
# 健
# 件
# a
# 健
# 建
# a
# 建
# 见
# a
# 建
# 荐
# a
# 建
# 件
# a
# 建
# 健
# a
# 意
# 易
# a
# 意
# 忆
# a
# 易
# 意
# a
# 易
# 忆
# a
# 忆
# 意
# a
# 忆
# 易
# a
# 经
# 京
# a
# 京
# 经
# a
# 演
# 眼
# a
# 眼
# 演
# a
# 美
# 每
# a
# 每
# 美
# a
# 做
# 作
# a
# 做
# 座
# a
# 做
# 坐
# a
# 作
# 做
# a
# 作
# 座
# a
# 作
# 坐
# a
# 座
# 做
# a
# 座
# 作
# a
# 座
# 坐
# a
# 坐
# 做
# a
# 坐
# 作
# a
# 坐
# 座
# a
# 七
# 期
# a
# 期
# 七
# a
# 提
# 题
# a
# 题
# 提
# a
# 系
# 戏
# a
# 戏
# 系
# a
# 近
# 进
# a
# 进
# 近
# a
# 服
# 福
# a
# 福
# 服
# a
# 诉
# 宿
# a
# 诉
# 速
# a
# 宿
# 诉
# a
# 宿
# 速
# a
# 速
# 诉
# a
# 速
# 宿
# a
# 玩
# 完
# a
# 完
# 玩
# a
# 网
# 往
# a
# 往
# 网
# a
# 文
# 闻
# a
# 闻
# 文
# a
# 只
# 址
# a
# 只
# 指
# a
# 址
# 只
# a
# 址
# 指
# a
# 指
# 只
# a
# 指
# 址
# a
# 记
# 计
# a
# 计
# 记
# a
# 又
# 右
# a
# 右
# 又
# a
# 无
# 吴
# a
# 吴
# 无
# a
# 同
# 童
# a
# 童
# 同
# a
# 正
# 郑
# a
# 正
# 证
# a
# 郑
# 正
# a
# 郑
# 证
# a
# 证
# 正
# a
# 证
# 郑
# a
# 火
# 伙
# a
# 伙
# 火
# a
# 目
# 木
# a
# 木
# 目
# a
# 南
# 难
# a
# 南
# 男
# a
# 难
# 南
# a
# 难
# 男
# a
# 男
# 南
# a
# 男
# 难
# a
# 负
# 复
# a
# 负
# 附
# a
# 负
# 父
# a
# 复
# 负
# a
# 复
# 附
# a
# 复
# 父
# a
# 附
# 负
# a
# 附
# 复
# a
# 附
# 父
# a
# 父
# 负
# a
# 父
# 复
# a
# 父
# 附
# a
# 动
# 冻
# a
# 冻
# 动
# a
# 英
# 应
# a
# 应
# 英
# a
# 注
# 祝
# a
# 祝
# 注
# a
# 司
# 思
# a
# 思
# 司
# a
# 非
# 飞
# a
# 飞
# 非
# a
# 克
# 客
# a
# 克
# 课
# a
# 客
# 克
# a
# 客
# 课
# a
# 课
# 克
# a
# 课
# 客
# a
# 齐
# 奇
# a
# 奇
# 齐
# a
# 办
# 半
# a
# 办
# 伴
# a
# 半
# 办
# a
# 半
# 伴
# a
# 伴
# 办
# a
# 伴
# 半
# a
# 江
# 将
# a
# 将
# 江
# a
# 预
# 遇
# a
# 遇
# 预
# a
# 宝
# 保
# a
# 保
# 宝
# a
# 相
# 香
# a
# 香
# 相
# a
# 前
# 钱
# a
# 钱
# 前
# a
# 西
# 息
# a
# 西
# 惜
# a
# 息
# 西
# a
# 息
# 惜
# a
# 惜
# 西
# a
# 惜
# 息
# a
# 于
# 鱼
# a
# 于
# 余
# a
# 鱼
# 于
# a
# 鱼
# 余
# a
# 余
# 于
# a
# 余
# 鱼
# a
# 青
# 清
# a
# 清
# 青
# a
# 姐
# 解
# a
# 解
# 姐
# a
# 成
# 城
# a
# 城
# 成
# a
# 书
# 舒
# a
# 舒
# 书
# a
# 贝
# 被
# a
# 贝
# 备
# a
# 贝
# 背
# a
# 被
# 贝
# a
# 被
# 备
# a
# 被
# 背
# a
# 备
# 贝
# a
# 备
# 被
# a
# 备
# 背
# a
# 背
# 贝
# a
# 背
# 被
# a
# 背
# 备
# a
# 亮
# 量
# a
# 量
# 亮
# a
# 但
# 蛋
# a
# 但
# 弹
# a
# 蛋
# 但
# a
# 蛋
# 弹
# a
# 弹
# 但
# a
# 弹
# 蛋
# a
# 夜
# 业
# a
# 业
# 夜
# a
# 星
# 兴
# a
# 兴
# 星
# a
# 力
# 立
# a
# 力
# 利
# a
# 立
# 力
# a
# 立
# 利
# a
# 利
# 力
# a
# 利
# 立
# a
# 制
# 治
# a
# 治
# 制
# a
# 带
# 代
# a
# 代
# 带
# a
# 静
# 敬
# a
# 敬
# 静
# a
# 笑
# 校
# a
# 校
# 笑
# a
# 普
# 谱
# a
# 谱
# 普
# a
# 交
# 郊
# a
# 郊
# 交
# a
# 句
# 剧
# a
# 剧
# 句
# a
# 琴
# 秦
# a
# 秦
# 琴
# a
# 络
# 落
# a
# 落
# 络
# a
# 购
# 够
# a
# 够
# 购
# a
# 数
# 术
# a
# 术
# 数
# a
# 忘
# 望
# a
# 望
# 忘
# a
# 凉
# 良
# a
# 凉
# 梁
# a
# 良
# 凉
# a
# 良
# 梁
# a
# 梁
# 凉
# a
# 梁
# 良
# a
# 累
# 类
# a
# 累
# 泪
# a
# 类
# 累
# a
# 类
# 泪
# a
# 泪
# 累
# a
# 泪
# 类
# a
# 断
# 段
# a
# 段
# 断
# a
# 围
# 维
# a
# 维
# 围
# a
# 务
# 物
# a
# 物
# 务
# a
# 赵
# 照
# a
# 照
# 赵
# a
# 嘿
# 黑
# a
# 黑
# 嘿
# a
# 介
# 界
# a
# 界
# 介
# a
# 杨
# 阳
# a
# 阳
# 杨
# a
# Average Baseline Similarity: 0.020245702224033917
# Average Homophone Group Similarity: 0.004315769230529173
# Difference Between Average Baseline and Homophone Similarities: 0.015929932993504745

# %%
import numpy as np
a = np.array([[0, 1, 0, 3], [1, 2, 3, 4], [2, 3, 4, 5]])
print(a[:, :-1] > a[:, 1:]  )
a[:, -1] > a[:, 0]
# Out:
# [[False  True False]
#  [False False False]
#  [False False False]]
# array([ True,  True,  True])
